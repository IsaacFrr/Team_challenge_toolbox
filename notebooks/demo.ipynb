# %%
import seaborn as sns
import pandas as pd
import numpy as np

from toolbox_ml.eda.core import describe_df

# %%
df = sns.load_dataset("titanic")

describe_df(df)
# Out:
#                  tipo  porcentaje_nulos  valores_unicos  \
# survived        int64          0.000000               2
# pclass          int64          0.000000               3
# sex               str          0.000000               2
# age           float64         19.865320              88
# sibsp           int64          0.000000               7
# parch           int64          0.000000               7
# fare          float64          0.000000             248
# embarked          str          0.224467               3
# class        category          0.000000               3
# who               str          0.000000               3
# adult_male       bool          0.000000               2
# deck         category         77.216611               7
# embark_town       str          0.224467               3
# alive             str          0.000000               2
# alone            bool          0.000000               2
#
#              porcentaje_cardinalidad
# ...
