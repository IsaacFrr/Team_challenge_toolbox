# %%
import seaborn as sns
import pandas as pd
import numpy as np

from toolbox_ml.eda.core import describe_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       1 import seaborn as sns
#       2 import pandas as pd
#       3 import numpy as np
#       4
# ----> 5 from toolbox_ml.eda.core import describe_df
#
# ModuleNotFoundError: No module named 'toolbox_ml'

# %%
df = sns.load_dataset("titanic")

describe_df(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 df = sns.load_dataset("titanic")
#       2
# ----> 3 describe_df(df)
#
# NameError: name 'describe_df' is not defined
