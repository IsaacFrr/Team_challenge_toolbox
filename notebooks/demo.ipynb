# %%
import seaborn as sns
import matplotlib.pyplot  as plt
import pandas as pd
import numpy as np

from toolbox_ml.eda.core import describe_df, tipifica_variables, get_features_cat_regression, plot_features_cat_regression

# %%
df = sns.load_dataset("titanic")

describe_df(df)
# Out:
#                  tipo  porcentaje_nulos  valores_unicos  \
# survived        int64              0.00               2
# pclass          int64              0.00               3
# sex               str              0.00               2
# age           float64             19.87              88
# sibsp           int64              0.00               7
# parch           int64              0.00               7
# fare          float64              0.00             248
# embarked          str              0.22               3
# class        category              0.00               3
# who               str              0.00               3
# adult_male       bool              0.00               2
# deck         category             77.22               7
# embark_town       str              0.22               3
# alive             str              0.00               2
# alone            bool              0.00               2
#
#              porcentaje_cardinalidad
# survived                        0.22
# pclass                          0.34
# sex                             0.22
# age                             9.88
# sibsp                           0.79
# parch                           0.79
# fare                           27.83
# embarked                        0.34
# class                           0.34
# who                             0.34
# adult_male                      0.22
# deck                            0.79
# embark_town                     0.34
# alive                           0.22
# alone                           0.22

# %%
plot_features_cat_regression(df, "fare", ["class", "survived", "sibsp", "sex"], with_individual_plot=False)

# %%
get_features_cat_regression(df, "fare")
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'sibsp',
#  'parch',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']
